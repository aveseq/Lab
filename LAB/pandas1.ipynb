# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['Aveseq','Harry','Rohan','Rahi'],
    "marks":[92,34,24,17],
    "city":['Rampur','Kolkata','Bareilly','Antartica']
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#      name  marks       city
# 0  Aveseq     92     Rampur
# 1   Harry     34    Kolkata
# 2   Rohan     24   Bareilly
# 3    Rahi     17  Antartica

# %%
df.to_csv('dict01.csv')

# %%
df.to_csv('index_F_dict01.csv', index=False)

# %%
print(df.head(2))
print(df.tail(2))
# Out:
#      name  marks     city
# 0  Aveseq     92   Rampur
# 1   Harry     34  Kolkata
#     name  marks       city
# 2  Rohan     24   Bareilly
# 3   Rahi     17  Antartica

# %%
print(df.describe())
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
aves = pd.read_csv('demoVIT.csv')
aves
# Out:
#         Student Name                         Student Email  \
# 0        Manan yadav               mananyadavgsb@gmail.com
# 1    Pratyush Mittal  pratyushmittal.2021@vitstudent.ac.in
# 2      Jagrat chopra             jagratchopra125@gmail.com
# 3        Hemant jha        hemant.jha2022@vitstudent.ac.in
# 4        Ritik nehra              ritiknehra07dz@gmail.com
# 5  Saadhikha Shree S               saadhikha1502@gmail.com
# 6     Varun Vashisht           varunvashisht2002@gmail.com
# 7  Ashutosh Bandooni                abandooni123@gmail.com
# 8     Gaurav Trivedi               gjtrivedi1099@gmail.com
#
#                                        Institution  \
# 0  Vellore Institute of Technology (VIT) - Chennai
# 1  Vellore Institute of Technology (VIT) - Chennai
# 2  Vellore Institute of Technology (VIT) - Chennai
# 3  Vellore Institute of Technology (VIT) - Chennai
# 4  Vellore Institute of Technology (VIT) - Chennai
# 5  Vellore Institute of Technology (VIT) - Chennai
# ...
