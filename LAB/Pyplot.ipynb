# %%
# Plotting Pyplot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#line plot
List1=range(10)
List2=[x*x for x in List1]
List1
List2
plt.plot(List1,List2)
plt.show()

# %%
List1=np.arange(1,20,2)
List2=np.arange(1,20,2)

plt.title("Line plot")
plt.xlabel("Range 1-20 in steps of 2")
plt.ylabel("Range 1-20 in steps of 2")
plt.plot(List1,List2)
plt.savefig(r"C:\Users\DR.Noor Mahammad SK\Desktop\plot1.jpg")
plt.show()

# %%
List1=np.arange(0,10,0.1)
List2=np.sin(List1)
List3=np.cos(List1)
plt.title("Sin and Cos Curve on List1")
plt.xlabel("0 to 10 (0.1)")
plt.ylabel("-1 to 1")
plt.plot(List1,List2,List1,List3)
# Out:
# [<matplotlib.lines.Line2D at 0x208cf60f940>,
#  <matplotlib.lines.Line2D at 0x208cf7a86d8>]

# %%
List1=np.arange(0,10,0.1)
List2=np.sin(List1)
List3=np.cos(List1)
plt.title("Sin Curve")
plt.xlabel("0 to 10 (0.1)")
plt.ylabel("-1 to 1")
plt.plot(List1,List2,List1,List3)
#Adding legends
plt.legend(['sin','cos'])
plt.savefig(r"C:\Users\DR.Noor Mahammad SK\Desktop\plot2.jpg")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
#Create lists 
x=np.arange(0,100,2) 
y=np.arange(50,-50,-2) 
y1=np.arange(100,0,-2) 
plt.title("With labels and different colors") 
plt.xlabel("Range 0 to 50") 
plt.ylabel("Range 50 to -50 ") 
plt.scatter(x,y,label="one",color='green') 
plt.scatter(x,y1,label="one",color='red') 
plt.legend(['A','B']) 
plt.savefig(r"C:\Users\DR.Noor Mahammad SK\Desktop\plot3.jpg") 
plt.show()

# %%
#Create lists
x=np.arange(0,100,2)
y=np.arange(50,-50,-2)
y1=np.arange(100,0,-2)
plt.figure(figsize=(5,5))
plt.title("With Gridlines and sized")
plt.xlabel("Range 0 to 50")
plt.ylabel("Range 50 to -50 ")

plt.grid(True)
plt.scatter(x,y,label="one",color='green')
plt.scatter(x,y1,label="one",color='red')
plt.legend(['A','B'])
#plt.savefig(r"C:\Users\DR.Noor Mahammad SK\Desktop\plot3.jpg")
plt.show()

# %% [markdown]
# # Twin axes plot

# %%
figure=plt.figure()
axes1=figure.add_subplot(1,1,1)
axes2=axes1.twinx()

List1=np.linspace(0.,10.,100)
List2=[x**2 for x in List1]
List3=[x**3 for x in List1]

axes1.plot(List1,List2,'b-')
axes2.plot(List1,List3,'r-')

axes1.set_ylabel('x power 2',color="red")
axes2.set_ylabel('x power 3',color="blue")
axes1.set_xlabel('x')
# Out:
# Text(0.5,0,'x')

# %% [markdown]
# # Colors, Markers, Line styles(Customize)

# %%
x=np.linspace(-3.14,3.14,100)
y=np.sin(x)
z=np.cos(x)
#plotting Curves
plt.plot(x,y,linewidth=5,c='#FA4500',linestyle='--')
plt.plot(x,z,c='b',marker='|',markersize=10)
plt.show()

# %% [markdown]
# # Bar Plots

# %%
df=pd.read_csv(r"C:\Users\DR.Noor Mahammad SK\Downloads\diabetes.csv")
#df.head()
df1=df.groupby("Insulin").agg({"Pregnancies":np.sum})
df1.head()
df1.to_csv(r"C:\Users\DR.Noor Mahammad SK\Downloads\diabetes_slice.csv")
df1.head(2)
# Out:
#          Pregnancies
# Insulin
# 0               1658
# 14                 0

# %%
years=('2015','2016','2017','2018','2019')
visitors=(1023,2034,1045,3405,4466)
index=np.arange(len(visitors))
bar_width=0.6
plt.bar(index,visitors,bar_width,color="red")
plt.show()

# %%
df=pd.read_csv(r"C:\Users\DR.Noor Mahammad SK\Downloads\diabetes_slice.csv")
insulin=df['Insulin']
pregnancies=df['Pregnancies']

Total=(df.shape)[0]
print(Total)

plt.xlim(0,max(df['Insulin']))
plt.ylim(0,max(df['Pregnancies']))
print(plt.xlim)

bar_width=10.0
plt.bar(insulin,pregnancies,bar_width,color='green')
#plt.show()
# Out:
# 186
# <function xlim at 0x00000208CE1C9268>
# <BarContainer object of 186 artists>

# %%
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],label="AAAA",width=.2)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],label="B",color='r',width=.5)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Some info...')
plt.show()

# %% [markdown]
# # Pie Charts

# %%
List1=['America','UK','Italy','Spain','China']
List2=[40,20,20,10,10]
explode=(0.2,0.1,0.1,0,0)
figure1, axes1=plt.subplots()
axes1.pie(List2,explode=explode,labels=List1,shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # AI Vs ML Vs DL

# %%
labels=[' AI Vs ML Vs DL ']
sizes=[100]
fig,ax1=plt.subplots()
ax1.pie(sizes,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90)
center_circle=plt.Circle((0,0),0.70,fc='white')
fig=plt.gcf()
fig.gca().add_artist(center_circle)
inner_circle=plt.Circle((0,0),0.30,fc='red')
fig=plt.gcf()
fig.gca().add_artist(inner_circle)

ax1.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Histograms

# %%
x=np.random.randint(20,size=(50))
num_bins=5
n,bins,patches=plt.hist(x,num_bins,facecolor='red',alpha=0.5,width=2)
print(n)
print(bins)
print(patches[0])
#plt.show()
# Out:
# [13.  8.  9. 10. 10.]
# [ 1.   4.6  8.2 11.8 15.4 19. ]
# Rectangle(xy=(1, 0), width=2, height=13, angle=0)

# %% [markdown]
# # 3D Plotting

# %%
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')

x=np.random.randint(5,size=(10))
y=np.random.randint(15,size=((10)))
z=np.random.randint(10,size=(10))

ax.scatter(x,y,z,c='r',marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# # Subplots

# %%
#Initialize the plot
Lt1=np.linspace(0.,10.,10)
Lt2=[x**2 for x in Lt1]
Lt3=[x**3 for x in Lt1]
Lt4=[np.sin(x) for x in Lt1]

fig=plt.figure(figsize=(20,8))
plt.title("Welcome to subplot")
ax1=fig.add_subplot(131)
#ax2=fig.add_subplot(132)
ax3=fig.add_subplot(133)
ax4=fig.add_subplot(231)
ax5=fig.add_subplot(232)
ax6=fig.add_subplot(233)
ax1.plot(np.arange(10),np.arange(0,20,2))
ax3.plot(Lt1,Lt2)
ax5.plot(Lt1,Lt3)
ax6.plot(Lt1,Lt4)
ax4.bar(Lt1,Lt2)
plt.tight_layout()
plt.show()

# %%
#INitilaize the plot
fig=plt.figure()
ax1=fig.add_subplot(131)
ax2=fig.add_subplot(133)

#plot the data
ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

#show the plot
plt.show()
